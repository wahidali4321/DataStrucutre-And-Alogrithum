# %% [markdown]
# # DataStructure and algorithum

# %% [markdown]
# ### 1. Second Largest Without Sorting

# %%
arr = [12, 45, 7, 23, 89, 34, 89, 56]
i = 0
for x in arr:
    arr[i] = arr[max]
    arr[max] = arr[i]

print(i)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 4
#       1 arr = [12, 45, 7, 23, 89, 34, 89, 56]
#       2 i = 0
#       3 for x in arr:
# ----> 4     arr[i] = arr[max]
#       5     arr[max] = arr[i]
#       6
#       7 print(i)
#
# TypeError: list indices must be integers or slices, not builtin_function_or_method

# %%
arr = [12, 45, 7, 23, 89, 34, 89, 56]

largest = float('-inf')
second_largest = float('-inf')

for x in arr:

    if x > largest:
        second_largest = largest
        largest = x

    elif x > second_largest and x != largest:
        second_largest = x

print("Largest:", largest)
print("Second largest:", second_largest)
# Out:
# Largest: 89
# Second largest: 56

# %%
arr = [12, 45, 7, 23, 89, 34, 89, 56]

largest = float('-inf')
second_largest = float('-inf')

for x in arr:
    if x > largest:
        second_largest = largest
        largest = x

    elif x > second_largest and x != largest:
        second_largest = x

print("Largest : " , largest)
print("second largest : " , second_largest)
# Out:
# Largest :  89
# second largest :  56

# %%
arr = [12, 45, 7, 23, 89, 34, 89, 56]
largest = float('-inf')
second_largest = float('-inf')

for x in arr:
    if x > largest:
        second_largest = largest
        largest = x

    elif x > second_largest and x != largest:
        second_largest = x

print("largest : " , largest)
print("second_largest" , second_largest)
# Out:
# largest :  89
# second_largest 56

# %% [markdown]
# ### Move All Zeros to End

# %%
arr = [0, 5, 0, 3, 8, 0, 2, 0, 7]

index = 0
for x in arr:
    if x != 0:
        arr[index] = x
        index += 1

while index < len(arr):
    arr[index] = 0
    index += 1

print(arr)
# Out:
# [5, 3, 8, 2, 7, 0, 0, 0, 0]

# %%
arr = [0, 5, 0, 3, 8, 0, 2, 0, 7]

index = 0
for x in arr:
    if x != 0:
        arr[index] = x
        index += 1

while index < len(arr):
    arr[index] = 0
    index += 1

print(arr)
# Out:
# [5, 3, 8, 2, 7, 0, 0, 0, 0]

# %% [markdown]
# ## Find Duplicate

# %%
arr = [1, 3, 4, 2, 5, 3, 6]

seen = []

for x in arr:

    if x in seen:
        print("Duplicate:", x)
        break

    seen.append(x)
# Out:
# Duplicate: 3

# %%
arr = [1,3,4,2,5,3,6]

seen = []

for x in arr:

    if x in seen:
        print("Duplicate: " , x)
        break

    seen.append(x)
# Out:
# Duplicate:  3

# %%
arr = ["wahid", "ali", "wahid"]

seen = []

for x in arr:

    if x in seen:
        print("Duplicate:", x)
        break

    seen.append(x)
# Out:
# Duplicate: wahid

# %% [markdown]
# #### Find the largest element without using max()

# %%
arr = [12, 45, 7, 23, 89, 34, 89, 56]
largest = float('-inf')
second_largest = float('-inf')

for x in arr:
    if x > largest:
        second_largest = largest
        largest = x

    elif second_largest > x or x != largest:
        second_largest = x

print("largest " , largest)
print("second_largest : " , second_largest)
# Out:
# largest  89
# second_largest :  56

# %%
arr = [12, 45, 7, 23, 89, 34, 89, 56]
largest = float('-inf')
second_largest = float('-inf')

for x in arr:
    if x > largest:
        
        largest = x

    

print("largest " , largest)
# Out:
# largest  89

# %% [markdown]
# ### Find the smallest element without using min().

# %%
arr = [12, 45, 7, 23, 89, 34, 89, 56]

smallest = arr[0]

for x in arr:
    if x < smallest:
        smallest = x

print("smallest : " , smallest)
# Out:
# smallest :  7

# %% [markdown]
# ## Find the second largest element without sorting

# %%
arr = [12, 45, 7, 23, 89, 34, 89, 56]

second_largest = float('-inf')
largest = float("-inf")

for x in arr:
    if largest > x:
        largest = second_largest
        largest = x

    elif second_largest > x or x != 0:
        second_largest = x

print("second_largest : " , second_largest)
# Out:
# second_largest :  56

# %% [markdown]
# ### Find the second smallest element without sorting.

# %%
arr = [12, 45, 7, 23, 89, 34, 89, 56]

smallest = arr[0]
s_smallest = arr[1]

for x in arr:
    if x < smallest:
        s_smallest = smallest
        smallest = x

    elif x < s_smallest and x != smallest:
        s_smallest = x

print("Second Smallest:", s_smallest)
# Out:
# Second Smallest: 12

# %% [markdown]
# #### Find the second largest unique element when duplicates exist

# %%
arr = [12, 45, 7, 23, 89, 34, 89, 569]

largest = float("-inf")
second_largest = float("-inf")
third_largest = float("-inf")

for x in arr:

    if x > largest:
        third_largest = second_largest
        second_largest = largest
        largest = x

    elif x > second_largest and x != largest:
        third_largest = second_largest
        second_largest = x

    elif x > third_largest and x != second_largest and x != largest:
        third_largest = x

print("Third Largest:", third_largest)
# Out:
# Third Largest: 45

# %% [markdown]
# ## Find the third largest element without sorting

# %%
arr = [12, 45, 7, 23, 89, 34, 89, 569]
largest = float('-inf')
second_largest = float('-inf')
third_largest = float('-inf')

for x in arr:
    if x > largest:
        third_largest = second_largest
        second_largest = largest
        largest = x

    elif x > third_largest and x != largest : 
        third_largest = second_largest
        second_largest = x
        

    elif x > third_largest and x != second_largest and x != largest:
        third_largest = x




print("Third largest : " , third_largest)
# Out:
# Third largest :  34

# %% [markdown]
# ### updated

# %%
arr = [12, 45, 7, 23, 89, 34, 89, 569]

largest = float('-inf')
second_largest = float('-inf')
third_largest = float('-inf')

for x in arr:

    if x > largest:
        third_largest = second_largest
        second_largest = largest
        largest = x

    elif x > second_largest and x != largest:
        third_largest = second_largest
        second_largest = x

    elif x > third_largest and x != second_largest and x != largest:
        third_largest = x

print("Third largest:", third_largest)
# Out:
# Third largest: 45

# %% [markdown]
# #### Find the third smallest element without sorting

# %%
arr = [12, 45, 7, 23, 89, 34, 89, 569]

smallest = float('inf')
smaller = float('inf')
small = float('inf')

for x in arr:
    if x < smallest:
        small = smaller
        smaller = smallest
        smallest = x

    elif x < smaller and x != smallest:
        small = smaller
        smaller = x


    elif x < smaller and x != smallest and x != small:
        small = x

print("smallest : " , small)
# Out:
# smallest :  45

# %% [markdown]
# #### updated

# %%
arr = [12, 45, 7, 23, 89, 34, 89, 569]

smallest = float('inf')
smaller = float('inf')
small = float('inf')

for x in arr:

    if x < smallest:
        small = smaller
        smaller = smallest
        smallest = x

    elif x < smaller and x != smallest:
        small = smaller
        smaller = x

    elif x < small and x != smallest and x != smaller:
        small = x

print("Third smallest:", small)
# Out:
# Third smallest: 23

# %% [markdown]
# #### Find the third smallest element without sorting

# %%
arr = [12, 45, 7, 23, 89, 34, 89, 569]
firstSmall = float('inf')
SecondSmall = float('inf')
thirdSmall = float('inf')

for x in arr:
    if x < firstSmall:
        thirdSmall = SecondSmall
        SecondSmall = firstSmall
        firstSmall = x

    elif x < SecondSmall and x != firstSmall:
        thirdSmall = SecondSmall
        SecondSmall = x

    elif x < thirdSmall and x != SecondSmall and x != firstSmall:
        thirdSmall = x


print("Third Small : " , thirdSmall)
# Out:
# Third Small :  23

# %% [markdown]
# #### Find the largest and smallest elements in one loop

# %%
arr = [12, 45, 7, 23, 89, 34, 89, 569]
firstSmall = float('inf')
SecondSmall = float('inf')
thirdSmall = float('inf')
largest = float('-inf')
second_largest = float('-inf')
third_largest = float('-inf')

for x in arr:
    if x > largest:
        third_largest = second_largest
        second_largest = largest
        largest = x

    elif x < firstSmall:
        thirdSmall = SecondSmall
        SecondSmall = firstSmall
        firstSmall = x

print("Largest : " , largest)
print("Smallest : " , firstSmall)
# Out:
# Largest :  569
# Smallest :  7

# %% [markdown]
# #### updated

# %%
arr = [12, 45, 7, 23, 89, 34, 89, 569]

smallest = float('inf')
largest = float('-inf')

for x in arr:

    if x > largest:
        largest = x

    if x < smallest:
        smallest = x

print("Largest:", largest)
print("Smallest:", smallest)
# Out:
# Largest: 569
# Smallest: 7

# %%
arr = [12, 45, 7, 23, 89, 34, 89, 569]
smallest = float('inf')
largest = float('-inf')

for x in arr:
    if x > largest:
        largest = x

    elif x < smallest:
        smallest = x

print("largest : " , largest)
print("smallest : " , smallest)
# Out:
# largest :  569
# smallest :  7

# %% [markdown]
# ##### Find the second largest negative number in an array

# %%
arr = [-11, -11, -14 , -17 , -333 , -500]
firstLarge = float('-inf')
second_largest = float('-inf')

for x in arr:
    if x > firstLarge:
        second_largest = firstLarge
        firstLarge = x

    elif x > second_largest and x != firstLarge:
        second_largest = x

print("Second largest : " , second_largest)
# Out:
# Second largest :  -14

# %% [markdown]
# ##### Find the k-th largest unique element without using sort() or sorted()

# %%
arr = [12, 45, 7, 23, 89, 34, 89, 56]
k = 3

largest = float('-inf')
second = float('-inf')
third = float('-inf')

for x in arr:

    if x > largest:
        third = second
        second = largest
        largest = x

    elif x > second and x != largest:
        third = second
        second = x

    elif x > third and x != largest and x != second:
        third = x

print("3rd largest unique:", third)
# Out:
# 3rd largest unique: 45

# %% [markdown]
# #### 2. Move Zeros — 10 Assignments

# %% [markdown]
# ##### Move all zeros to the end while preserving order

# %%
arr = [0, 5, 0, 3, 8, 0, 2, 0, 7]

index = 0
for x in arr:
    if x != 0:
        arr[index] = x
        index += 1

while index < len(arr):
    arr[index] = 0
    index += 1

print(arr)
# Out:
# [5, 3, 8, 2, 7, 0, 0, 0, 0]

# %%
arr = [0, 5, 0, 3, 8, 0, 2, 0, 7 , 0]

index = 0
for x in arr:
    if x != 0:
        arr[index] = x
        index += 1

while index < len(arr):
    arr[index] = 0
    index += 1

print(arr)
# Out:
# [5, 3, 8, 2, 7, 0, 0, 0, 0, 0]

# %% [markdown]
# #### Move all zeros to the beginning

# %%
arr = [0, 5, 0, 3, 8, 0, 2, 0, 7, 0]

index = 0

for x in arr:
    if x == 0:
        arr[index] = 0
        index += 1

for x in arr:
    if x != 0:
        arr[index] = x
        index += 1

print(arr)
# Out:
# [0, 0, 0, 0, 0, 2, 7, 0, 7, 0]

# %% [markdown]
# #### updated

# %%
arr = [0, 5, 0, 3, 8, 0, 2, 0, 7, 0]

index = 0

# Put zeros at the beginning
for x in arr:
    if x == 0:
        arr[index] = 0
        index += 1

# Put non-zero values after the zeros
for x in [5, 3, 8, 2, 7]:
    arr[index] = x
    index += 1

print(arr)
# Out:
# [0, 0, 0, 0, 0, 5, 3, 8, 2, 7]

# %% [markdown]
# #### Move all negative numbers to the beginning

# %%
arr = [0, 5, 0, 3, 8, 0, 2]

index = 0

for x in arr:
    if x < 0:
        arr[index] = 0
        index += 1

    elif x > 0:
        arr[index] = 0
        index += 1

print(arr)
# Out:
# [0, 0, 0, 0, 8, 0, 2]

# %% [markdown]
# ### updated

# %%
arr = [0, 5, 0, 3, 8, 0, -2]

index = 0

for x in arr:
    if x < 0:
        arr[index] = 0
        index += 1

    elif x > 0:
        arr[index] = 0
        index += 1

print(arr)
# Out:
# [0, 0, 0, 0, 8, 0, -2]

# %%
arr = [0, 5, 0, 3, 8, 0, 2]

index = len(arr) - 1

for x in arr[::-1]:
    if x != 0:
        arr[index] = x
        index -= 1

while index >= 0:
    arr[index] = 0
    index -= 1

print(arr)
# Out:
# [0, 0, 0, 5, 3, 8, 2]

# %%
arr = [0 , 5 , 0 , 3 , 8 , 0 , 2]

index = len(arr) - 1
for x in arr[::-1]:
    if x != 0:
        arr[index] = x
        index -= 1

while index >= 0:
    arr[index] = 0
    index -= 1

print(arr)
# Out:
# [0, 0, 0, 5, 3, 8, 2]

# %%
arr = [0 , 5 , 0 , 3 , 8 , 0 , 2]
index = len(arr) - 1

for x in arr[::-1]:
    if x != 0:
        arr[index] = x
        index -= 1

while index >= 0:
    arr[index] = 0
    index -= 1

print(arr)
# Out:
# [0, 0, 0, 5, 3, 8, 2]

# %%
arr = [0, 5, -3, 8, -2, 7, 0, -6]

index = 0

for x in arr:
    if x > 0:
        arr[index] = x
        index += 1

for x in arr:
    if x <= 0:
        arr[index] = x
        index += 1

print(arr)
# Out:
# [5, 8, 7, -2, 0, -6, 0, -6]

# %% [markdown]
# #### Bubble Sort

# %%
my_array = [64, 34, 25, 12, 22, 11, 90, 5]

n = len(my_array)
for i in range(n-1):
    for j in range(n-i-1):
        if my_array[j] > my_array[j+1]:
            my_array[j], my_array[j+1] = my_array[j+1], my_array[j]

print("Sorted array:", my_array)
# Out:
# Sorted array: [5, 11, 12, 22, 25, 34, 64, 90]

# %% [markdown]
# ##### practise

# %%
my_array = [64 , 34 , 25 , 12 , 11 , 90 , 5]
n = len(my_array)

for i in range(n - 1):
    for j in range(n - i - 1):
        if my_array[j] > my_array[j + 1]:
            my_array[j] ,  my_array[j + 1] = my_array[j + 1] , my_array[j]

print('Sorted Array : ' , my_array)
# Out:
# Sorted Array :  [5, 11, 12, 25, 34, 64, 90]
